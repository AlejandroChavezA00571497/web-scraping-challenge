# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
soup_obj = soup(html, 'html.parser')

# %%
# Extract all rows of data

table = soup_obj.find_all("tr", class_ = "data-row")

rows = [row.get_text() for row in table]

row_data = []
for row in rows:
    row_data_new = row.splitlines()
    row_data.append(row_data_new)

print(row_data)
# Out:
# [['', '2', '2012-08-16', '10', '155', '6', '-75.0', '739.0'], ['', '13', '2012-08-17', '11', '156', '6', '-76.0', '740.0'], ['', '24', '2012-08-18', '12', '156', '6', '-76.0', '741.0'], ['', '35', '2012-08-19', '13', '157', '6', '-74.0', '732.0'], ['', '46', '2012-08-20', '14', '157', '6', '-74.0', '740.0'], ['', '57', '2012-08-21', '15', '158', '6', '-78.0', '740.0'], ['', '68', '2012-08-22', '16', '158', '6', '-77.0', '740.0'], ['', '79', '2012-08-23', '17', '159', '6', '-76.0', '742.0'], ['', '112', '2012-08-27', '21', '161', '6', '-74.0', '741.0'], ['', '114', '2012-08-28', '22', '162', '6', '-74.0', '742.0'], ['', '123', '2012-08-29', '23', '162', '6', '-75.0', '741.0'], ['', '134', '2012-08-30', '24', '163', '6', '-75.0', '742.0'], ['', '145', '2012-08-31', '25', '163', '6', '-75.0', '743.0'], ['', '156', '2012-09-01', '26', '164', '6', '-76.0', '745.0'], ['', '163', '2012-09-02', '27', '164', '6', '-75.0', '743.0'], ['', '170', '2012-09-03', '28', '165', '6', '-75.0', '745.0'], ['', '171', '2012-09-04', '29', '166', '6', '-75.0', '747.0'], ['', '172', '2012-09-05', '30', '166', '6', '-74.0', '747.0'], ['', '173', '2012-09-06', '31', '167', '6', '-74.0', '745.0'], ['', '175', '2012-09-08', '33', '168', '6', '-73.0', '748.0'], ['', '176', '2012-09-10', '34', '168', '6', '-73.0', '748.0'], ['', '177', '2012-09-11', '35', '169', '6', '-73.0', '749.0'], ['', '178', '2012-09-12', '36', '169', '6', '-73.0', '750.0'], ['', '179', '2012-09-13', '37', '170', '6', '-73.0', '750.0'], ['', '180', '2012-09-14', '38', '171', '6', '-73.0', '750.0'], ['', '181', '2012-09-15', '39', '171', '6', '-75.0', '751.0'], ['', '182', '2012-09-16', '40', '172', '6', '-75.0', '753.0'], ['', '183', '2012-09-17', '41', '172', '6', '-75.0', '753.0'], ['', '184', '2012-09-18', '42', '173', '6', '-75.0', '754.0'], ['', '185', '2012-09-19', '43', '173', '6', '-74.0', '756.0'], ['', '186', '2012-09-20', '44', '174', '6', '-75.0', '757.0'], ['', '187', '2012-09-21', '45', '175', '6', '-74.0', '758.0'], ['', '188', '2012-09-22', '46', '175', '6', '-74.0', '758.0'], ['', '189', '2012-09-23', '47', '176', '6', '-75.0', '758.0'], ['', '190', '2012-09-24', '48', '176', '6', '-75.0', '759.0'], ['', '191', '2012-09-25', '49', '177', '6', '-74.0', '761.0'], ['', '192', '2012-09-26', '50', '177', '6', '-72.0', '761.0'], ['', '193', '2012-09-27', '51', '178', '6', '-76.0', '762.0'], ['', '194', '2012-09-28', '52', '179', '6', '-74.0', '762.0'], ['', '195', '2012-09-29', '53', '179', '6', '-71.0', '764.0'], ['', '196', '2012-09-30', '54', '180', '7', '-72.0', '766.0'], ['', '197', '2012-10-01', '55', '180', '7', '-74.0', '766.0'], ['', '198', '2012-10-02', '56', '181', '7', '-73.0', '768.0'], ['', '199', '2012-10-03', '57', '181', '7', '-73.0', '769.0'], ['', '200', '2012-10-04', '58', '182', '7', '-74.0', '769.0'], ['', '201', '2012-10-05', '59', '183', '7', '-76.0', '771.0'], ['', '202', '2012-10-06', '60', '183', '7', '-75.0', '772.0'], ['', '203', '2012-10-07', '61', '184', '7', '-72.0', '772.0'], ['', '204', '2012-10-08', '62', '184', '7', '-72.0', '774.0'], ['', '205', '2012-10-09', '63', '185', '7', '-73.0', '775.0'], ['', '206', '2012-10-10', '64', '186', '7', '-74.0', '776.0'], ['', '207', '2012-10-11', '65', '186', '7', '-72.0', '777.0'], ['', '208', '2012-10-12', '66', '187', '7', '-73.0', '778.0'], ['', '209', '2012-10-13', '67', '187', '7', '-73.0', '780.0'], ['', '210', '2012-10-14', '68', '188', '7', '-71.0', '781.0'], ['', '211', '2012-10-15', '69', '189', '7', '-73.0', '778.0'], ['', '212', '2012-10-17', '70', '189', '7', '-72.0', '783.0'], ['', '213', '2012-10-18', '71', '190', '7', '-71.0', '784.0'], ['', '214', '2012-10-19', '72', '190', '7', '-73.0', '785.0'], ['', '215', '2012-10-20', '73', '191', '7', '-70.0', '788.0'], ['', '216', '2012-10-21', '74', '192', '7', '-72.0', '790.0'], ['', '217', '2012-10-22', '75', '192', '7', '-73.0', '791.0'], ['', '218', '2012-10-23', '76', '193', '7', '-73.0', '792.0'], ['', '219', '2012-10-24', '77', '193',  ...
# '\nrow_data = [row.get_text() for row in table]\n\nrow_data_complete = []\nfor row in row_data:\n    new_row = row.splitlines()\n    row_data_complete.append(new_row)\n\n\nrow_data_complete\n'

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
weather_data_list = []

# Loop through the scraped data to create a list of rows
for row in row_data:
    row_dict = {}
    row_dict["id"] = row[1]
    row_dict["terrestrial_data"] = row[2]
    row_dict["sol"] = row[3]
    row_dict["ls"] = row[4]
    row_dict["month"] = row[5]
    row_dict["min_temp"] = row[6]
    row_dict["pressure"] = row[7]
    weather_data_list.append(row_dict)

weather_data_list
# Out:
# [{'id': '2',
#   'terrestrial_data': '2012-08-16',
#   'sol': '10',
#   'ls': '155',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '739.0'},
#  {'id': '13',
#   'terrestrial_data': '2012-08-17',
#   'sol': '11',
#   'ls': '156',
#   'month': '6',
#   'min_temp': '-76.0',
#   'pressure': '740.0'},
#  {'id': '24',
#   'terrestrial_data': '2012-08-18',
#   'sol': '12',
#   'ls': '156',
#   'month': '6',
#   'min_temp': '-76.0',
#   'pressure': '741.0'},
#  {'id': '35',
#   'terrestrial_data': '2012-08-19',
#   'sol': '13',
#   'ls': '157',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '732.0'},
#  {'id': '46',
#   'terrestrial_data': '2012-08-20',
#   'sol': '14',
#   'ls': '157',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '740.0'},
#  {'id': '57',
#   'terrestrial_data': '2012-08-21',
#   'sol': '15',
#   'ls': '158',
#   'month': '6',
#   'min_temp': '-78.0',
#   'pressure': '740.0'},
#  {'id': '68',
#   'terrestrial_data': '2012-08-22',
#   'sol': '16',
#   'ls': '158',
#   'month': '6',
#   'min_temp': '-77.0',
#   'pressure': '740.0'},
#  {'id': '79',
#   'terrestrial_data': '2012-08-23',
#   'sol': '17',
#   'ls': '159',
#   'month': '6',
#   'min_temp': '-76.0',
#   'pressure': '742.0'},
#  {'id': '112',
#   'terrestrial_data': '2012-08-27',
#   'sol': '21',
#   'ls': '161',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '741.0'},
#  {'id': '114',
#   'terrestrial_data': '2012-08-28',
#   'sol': '22',
#   'ls': '162',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '742.0'},
#  {'id': '123',
#   'terrestrial_data': '2012-08-29',
#   'sol': '23',
#   'ls': '162',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '741.0'},
#  {'id': '134',
#   'terrestrial_data': '2012-08-30',
#   'sol': '24',
#   'ls': '163',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '742.0'},
#  {'id': '145',
#   'terrestrial_data': '2012-08-31',
#   'sol': '25',
#   'ls': '163',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '743.0'},
#  {'id': '156',
#   'terrestrial_data': '2012-09-01',
#   'sol': '26',
#   'ls': '164',
#   'month': '6',
#   'min_temp': '-76.0',
#   'pressure': '745.0'},
#  {'id': '163',
#   'terrestrial_data': '2012-09-02',
#   'sol': '27',
#   'ls': '164',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '743.0'},
#  {'id': '170',
#   'terrestrial_data': '2012-09-03',
#   'sol': '28',
#   'ls': '165',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '745.0'},
#  {'id': '171',
#   'terrestrial_data': '2012-09-04',
#   'sol': '29',
#   'ls': '166',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '747.0'},
#  {'id': '172',
#   'terrestrial_data': '2012-09-05',
#   'sol': '30',
#   'ls': '166',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '747.0'},
#  {'id': '173',
#   'terrestrial_data': '2012-09-06',
#   'sol': '31',
#   'ls': '167',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '745.0'},
#  {'id': '175',
#   'terrestrial_data': '2012-09-08',
#   'sol': '33',
#   'ls': '168',
#   'month': '6',
#   'min_temp': '-73.0',
#   'pressure': '748.0'},
#  {'id': '176',
#   'terrestrial_data': '2012-09-10',
#   'sol': '34',
#   'ls': '168',
#   'month': '6',
#   'min_temp': '-73.0',
#   'pressure': '748.0'},
#  {'id': '177',
#   'terrestrial_data': '2012-09-11',
#   'sol': '35',
#   'ls': '169',
#   'month': '6',
#   'min_temp': '-73.0',
#   'pressure': '749.0'},
#  {'id': '178',
#   'terrestrial_data': '2012-09-12',
#   'sol': '36',
#   'ls': '169',
#   'month': '6',
#   'min_temp': '-73.0',
#   'pressure': '750.0'},
#  {'id': '179',
#   'terrestrial_data': '2012-09-13',
#   'sol': '37',
#   'ls': '170',
#   'month': '6',
#   'min_temp': '-73.0',
#   'pressure': '750.0'},
#  {'id': '180',
#   'terrestrial_data': '2012-09-14',
#   'sol': '38',
#   'ls': '171',
#   'month': '6',
#   'min_temp': '-73.0',
#   'pressure': '750.0'},
#  {'id': '181',
#   'terrestrial_data': '2012-09-15',
#   'sol': '39',
#   'ls': '171',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '751.0'},
#  {'id': '182',
#   'terrestrial_data': '2012-09-16',
#   'sol': '40',
#   'ls': '172',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '753.0'},
#  {'id': '183',
#   'terrestrial_data': '2012-09-17',
#   'sol': '41',
#   'ls': '172',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '753.0'},
#  {'id': '184',
#   'terrestrial_data': '2012-09-18',
#   'sol': '42',
#   'ls': '173',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '754.0'},
#  {'id': '185',
#   'terrestrial_data': '2012-09-19',
#   'sol': '43',
#   'ls': '173',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '756.0'},
#  {'id': '186',
#   'terrestrial_data': '2012-09-20',
#   'sol': '44',
#   'ls': '174',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '757.0'},
#  {'id': '187',
#   'terrestrial_data': '2012-09-21',
#   'sol': '45',
#   'ls': '175',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '758.0'},
#  {'id': '188',
#   'terrestrial_data': '2012-09-22',
#   'sol': '46',
#   'ls': '175',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '758.0'},
#  {'id': '189',
#   'terrestrial_data': '2012-09-23',
#   'sol': '47',
#   'ls': '176',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '758.0'},
#  {'id': '190',
#   'terrestrial_data': '2012-09-24',
#   'sol': '48',
#   'ls': '176',
#   'month': '6',
#   'min_temp': '-75.0',
#   'pressure': '759.0'},
#  {'id': '191',
#   'terrestrial_data': '2012-09-25',
#   'sol': '49',
#   'ls': '177',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '761.0'},
#  {'id': '192',
#   'terrestrial_data': '2012-09-26',
#   'sol': '50',
#   'ls': '177',
#   'month': '6',
#   'min_temp': '-72.0',
#   'pressure': '761.0'},
#  {'id': '193',
#   'terrestrial_data': '2012-09-27',
#   'sol': '51',
#   'ls': '178',
#   'month': '6',
#   'min_temp': '-76.0',
#   'pressure': '762.0'},
#  {'id': '194',
#   'terrestrial_data': '2012-09-28',
#   'sol': '52',
#   'ls': '179',
#   'month': '6',
#   'min_temp': '-74.0',
#   'pressure': '762.0'},
#  {'id': '195',
#   'terrestrial_data': '2012-09-29',
#   'sol': '53',
#   'ls': '179',
#   'month': '6',
#   'min_temp': '-71.0',
#   'pressure': '764.0'},
#  {'id': '196',
#   'terrestrial_data': '2012-09-30',
#   'sol': '54',
#   'ls': '180',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '766.0'},
#  {'id': '197',
#   'terrestrial_data': '2012-10-01',
#   'sol': '55',
#   'ls': '180',
#   'month': '7',
#   'min_temp': '-74.0',
#   'pressure': '766.0'},
#  {'id': '198',
#   'terrestrial_data': '2012-10-02',
#   'sol': '56',
#   'ls': '181',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '768.0'},
#  {'id': '199',
#   'terrestrial_data': '2012-10-03',
#   'sol': '57',
#   'ls': '181',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '769.0'},
#  {'id': '200',
#   'terrestrial_data': '2012-10-04',
#   'sol': '58',
#   'ls': '182',
#   'month': '7',
#   'min_temp': '-74.0',
#   'pressure': '769.0'},
#  {'id': '201',
#   'terrestrial_data': '2012-10-05',
#   'sol': '59',
#   'ls': '183',
#   'month': '7',
#   'min_temp': '-76.0',
#   'pressure': '771.0'},
#  {'id': '202',
#   'terrestrial_data': '2012-10-06',
#   'sol': '60',
#   'ls': '183',
#   'month': '7',
#   'min_temp': '-75.0',
#   'pressure': '772.0'},
#  {'id': '203',
#   'terrestrial_data': '2012-10-07',
#   'sol': '61',
#   'ls': '184',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '772.0'},
#  {'id': '204',
#   'terrestrial_data': '2012-10-08',
#   'sol': '62',
#   'ls': '184',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '774.0'},
#  {'id': '205',
#   'terrestrial_data': '2012-10-09',
#   'sol': '63',
#   'ls': '185',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '775.0'},
#  {'id': '206',
#   'terrestrial_data': '2012-10-10',
#   'sol': '64',
#   'ls': '186',
#   'month': '7',
#   'min_temp': '-74.0',
#   'pressure': '776.0'},
#  {'id': '207',
#   'terrestrial_data': '2012-10-11',
#   'sol': '65',
#   'ls': '186',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '777.0'},
#  {'id': '208',
#   'terrestrial_data': '2012-10-12',
#   'sol': '66',
#   'ls': '187',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '778.0'},
#  {'id': '209',
#   'terrestrial_data': '2012-10-13',
#   'sol': '67',
#   'ls': '187',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '780.0'},
#  {'id': '210',
#   'terrestrial_data': '2012-10-14',
#   'sol': '68',
#   'ls': '188',
#   'month': '7',
#   'min_temp': '-71.0',
#   'pressure': '781.0'},
#  {'id': '211',
#   'terrestrial_data': '2012-10-15',
#   'sol': '69',
#   'ls': '189',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '778.0'},
#  {'id': '212',
#   'terrestrial_data': '2012-10-17',
#   'sol': '70',
#   'ls': '189',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '783.0'},
#  {'id': '213',
#   'terrestrial_data': '2012-10-18',
#   'sol': '71',
#   'ls': '190',
#   'month': '7',
#   'min_temp': '-71.0',
#   'pressure': '784.0'},
#  {'id': '214',
#   'terrestrial_data': '2012-10-19',
#   'sol': '72',
#   'ls': '190',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '785.0'},
#  {'id': '215',
#   'terrestrial_data': '2012-10-20',
#   'sol': '73',
#   'ls': '191',
#   'month': '7',
#   'min_temp': '-70.0',
#   'pressure': '788.0'},
#  {'id': '216',
#   'terrestrial_data': '2012-10-21',
#   'sol': '74',
#   'ls': '192',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '790.0'},
#  {'id': '217',
#   'terrestrial_data': '2012-10-22',
#   'sol': '75',
#   'ls': '192',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '791.0'},
#  {'id': '218',
#   'terrestrial_data': '2012-10-23',
#   'sol': '76',
#   'ls': '193',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '792.0'},
#  {'id': '219',
#   'terrestrial_data': '2012-10-24',
#   'sol': '77',
#   'ls': '193',
#   'month': '7',
#   'min_temp': '-71.0',
#   'pressure': '792.0'},
#  {'id': '220',
#   'terrestrial_data': '2012-10-25',
#   'sol': '78',
#   'ls': '194',
#   'month': '7',
#   'min_temp': '-71.0',
#   'pressure': '793.0'},
#  {'id': '221',
#   'terrestrial_data': '2012-10-26',
#   'sol': '79',
#   'ls': '195',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '795.0'},
#  {'id': '222',
#   'terrestrial_data': '2012-10-27',
#   'sol': '80',
#   'ls': '195',
#   'month': '7',
#   'min_temp': '-70.0',
#   'pressure': '796.0'},
#  {'id': '223',
#   'terrestrial_data': '2012-10-28',
#   'sol': '81',
#   'ls': '196',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '798.0'},
#  {'id': '224',
#   'terrestrial_data': '2012-10-29',
#   'sol': '82',
#   'ls': '196',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '799.0'},
#  {'id': '225',
#   'terrestrial_data': '2012-10-30',
#   'sol': '83',
#   'ls': '197',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '801.0'},
#  {'id': '226',
#   'terrestrial_data': '2012-10-31',
#   'sol': '84',
#   'ls': '198',
#   'month': '7',
#   'min_temp': '-70.0',
#   'pressure': '801.0'},
#  {'id': '227',
#   'terrestrial_data': '2012-11-01',
#   'sol': '85',
#   'ls': '198',
#   'month': '7',
#   'min_temp': '-71.0',
#   'pressure': '805.0'},
#  {'id': '228',
#   'terrestrial_data': '2012-11-02',
#   'sol': '86',
#   'ls': '199',
#   'month': '7',
#   'min_temp': '-71.0',
#   'pressure': '808.0'},
#  {'id': '229',
#   'terrestrial_data': '2012-11-03',
#   'sol': '87',
#   'ls': '199',
#   'month': '7',
#   'min_temp': '-70.0',
#   'pressure': '808.0'},
#  {'id': '230',
#   'terrestrial_data': '2012-11-04',
#   'sol': '88',
#   'ls': '200',
#   'month': '7',
#   'min_temp': '-70.0',
#   'pressure': '811.0'},
#  {'id': '231',
#   'terrestrial_data': '2012-11-05',
#   'sol': '89',
#   'ls': '201',
#   'month': '7',
#   'min_temp': '-73.0',
#   'pressure': '813.0'},
#  {'id': '233',
#   'terrestrial_data': '2012-11-06',
#   'sol': '90',
#   'ls': '201',
#   'month': '7',
#   'min_temp': '-71.0',
#   'pressure': '813.0'},
#  {'id': '234',
#   'terrestrial_data': '2012-11-07',
#   'sol': '91',
#   'ls': '202',
#   'month': '7',
#   'min_temp': '-74.0',
#   'pressure': '817.0'},
#  {'id': '235',
#   'terrestrial_data': '2012-11-08',
#   'sol': '92',
#   'ls': '202',
#   'month': '7',
#   'min_temp': '-74.0',
#   'pressure': '820.0'},
#  {'id': '236',
#   'terrestrial_data': '2012-11-09',
#   'sol': '93',
#   'ls': '203',
#   'month': '7',
#   'min_temp': '-72.0',
#   'pressure': '819.0'},
#  {'id': '237',
#   'terrestrial_data': '2012-11-10',
#   'sol': '94',
#   'ls': '204',
#   'month': '7',
#   'min_temp': '-70.0',
#   'pressure': '822.0'},
#  {'id': '238',
#   'terrestrial_data': '2012-11-11',
#   'sol': '95',
#   'ls': '204',
#   'month': '7',
#   'min_temp': '-68.0',
#   'pressure': '822.0'},
#  {'id': '239',
#   'terrestrial_data': '2012-11-12',
#   'sol': '96',
#   'ls': '205',
#   'month': '7',
#   'min_temp': '-71.0',
#   'pressure': '826.0'},
#  {'id': '240',
#   'terrestrial_data': '2012-11-13',
#   'sol': '97',
#   'ls': '206',
#   'month': '7',
#   'min_temp': '-68.0',
#   'pressure': '828.0'},
#  {'id': '241',
#   'terrestrial_data': '2012-11-14',
#   'sol': '98',
#   'ls': '206',
#   'month': '7',
#   'min_temp': '-68.0',
#   'pressure': '828.0'},
#  {'id': '242',
#   'terrestrial_data': '2012-11-15',
#   'sol': '99',
#   'ls': '207',
#   'month': '7',
#   'min_temp': '-68.0',
#   'pressure': '829.0'},
#  {'id': '3',
#   'terrestrial_data': '2012-11-16',
#   'sol': '100',
#   'ls': '207',
#   'month': '7',
#   'min_temp': '-66.0',
#   'pressure': '829.0'},
#  {'id': '4',
#   'terrestrial_data': '2012-11-17',
#   'sol': '101',
#   'ls': '208',
#   'month': '7',
#   'min_temp': '-65.0',
#   'pressure': '830.0'},
#  {'id': '5',
#   'terrestrial_data': '2012-11-18',
#   'sol': '102',
#   'ls': '209',
#   'month': '7',
#   'min_temp': '-67.0',
#   'pressure': '833.0'},
#  {'id': '6',
#   'terrestrial_data': '2012-11-19',
#   'sol': '103',
#   'ls': '209',
#   'month': '7',
#   'min_temp': '-66.0',
#   'pressure': '836.0'},
#  {'id': '7',
#   'terrestrial_data': '2012-11-20',
#   'sol': '104',
#   'ls': '210',
#   'month': '8',
#   'min_temp': '-67.0',
#   'pressure': '838.0'},
#  {'id': '8',
#   'terrestrial_data': '2012-11-21',
#   'sol': '105',
#   'ls': '211',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '839.0'},
#  {'id': '9',
#   'terrestrial_data': '2012-11-23',
#   'sol': '106',
#   'ls': '211',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '841.0'},
#  {'id': '10',
#   'terrestrial_data': '2012-11-24',
#   'sol': '107',
#   'ls': '212',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '844.0'},
#  {'id': '11',
#   'terrestrial_data': '2012-11-25',
#   'sol': '108',
#   'ls': '212',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '845.0'},
#  {'id': '12',
#   'terrestrial_data': '2012-11-26',
#   'sol': '109',
#   'ls': '213',
#   'month': '8',
#   'min_temp': '-64.0',
#   'pressure': '844.0'},
#  {'id': '14',
#   'terrestrial_data': '2012-11-27',
#   'sol': '110',
#   'ls': '214',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '848.0'},
#  {'id': '15',
#   'terrestrial_data': '2012-11-28',
#   'sol': '111',
#   'ls': '214',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '849.0'},
#  {'id': '16',
#   'terrestrial_data': '2012-11-29',
#   'sol': '112',
#   'ls': '215',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '852.0'},
#  {'id': '17',
#   'terrestrial_data': '2012-11-30',
#   'sol': '113',
#   'ls': '216',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '857.0'},
#  {'id': '18',
#   'terrestrial_data': '2012-12-01',
#   'sol': '114',
#   'ls': '216',
#   'month': '8',
#   'min_temp': '-69.0',
#   'pressure': '857.0'},
#  {'id': '19',
#   'terrestrial_data': '2012-12-02',
#   'sol': '115',
#   'ls': '217',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '857.0'},
#  {'id': '20',
#   'terrestrial_data': '2012-12-03',
#   'sol': '116',
#   'ls': '217',
#   'month': '8',
#   'min_temp': '-67.0',
#   'pressure': '859.0'},
#  {'id': '21',
#   'terrestrial_data': '2012-12-04',
#   'sol': '117',
#   'ls': '218',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '861.0'},
#  {'id': '22',
#   'terrestrial_data': '2012-12-05',
#   'sol': '118',
#   'ls': '219',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '864.0'},
#  {'id': '23',
#   'terrestrial_data': '2012-12-06',
#   'sol': '119',
#   'ls': '219',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '866.0'},
#  {'id': '25',
#   'terrestrial_data': '2012-12-07',
#   'sol': '120',
#   'ls': '220',
#   'month': '8',
#   'min_temp': '-67.0',
#   'pressure': '867.0'},
#  {'id': '26',
#   'terrestrial_data': '2012-12-08',
#   'sol': '121',
#   'ls': '221',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '869.0'},
#  {'id': '27',
#   'terrestrial_data': '2012-12-09',
#   'sol': '122',
#   'ls': '221',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '869.0'},
#  {'id': '28',
#   'terrestrial_data': '2012-12-10',
#   'sol': '123',
#   'ls': '222',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '875.0'},
#  {'id': '29',
#   'terrestrial_data': '2012-12-11',
#   'sol': '124',
#   'ls': '223',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '876.0'},
#  {'id': '30',
#   'terrestrial_data': '2012-12-12',
#   'sol': '125',
#   'ls': '223',
#   'month': '8',
#   'min_temp': '-68.0',
#   'pressure': '880.0'},
#  {'id': '31',
#   'terrestrial_data': '2012-12-13',
#   'sol': '126',
#   'ls': '224',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '880.0'},
#  {'id': '32',
#   'terrestrial_data': '2012-12-14',
#   'sol': '127',
#   'ls': '224',
#   'month': '8',
#   'min_temp': '-67.0',
#   'pressure': '884.0'},
#  {'id': '33',
#   'terrestrial_data': '2012-12-15',
#   'sol': '128',
#   'ls': '225',
#   'month': '8',
#   'min_temp': '-67.0',
#   'pressure': '883.0'},
#  {'id': '34',
#   'terrestrial_data': '2012-12-16',
#   'sol': '129',
#   'ls': '226',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '886.0'},
#  {'id': '36',
#   'terrestrial_data': '2012-12-17',
#   'sol': '130',
#   'ls': '226',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '888.0'},
#  {'id': '37',
#   'terrestrial_data': '2012-12-18',
#   'sol': '131',
#   'ls': '227',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '889.0'},
#  {'id': '38',
#   'terrestrial_data': '2012-12-19',
#   'sol': '132',
#   'ls': '228',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '890.0'},
#  {'id': '39',
#   'terrestrial_data': '2012-12-20',
#   'sol': '133',
#   'ls': '228',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '891.0'},
#  {'id': '40',
#   'terrestrial_data': '2012-12-21',
#   'sol': '134',
#   'ls': '229',
#   'month': '8',
#   'min_temp': '-67.0',
#   'pressure': '893.0'},
#  {'id': '41',
#   'terrestrial_data': '2012-12-22',
#   'sol': '135',
#   'ls': '230',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '894.0'},
#  {'id': '42',
#   'terrestrial_data': '2012-12-23',
#   'sol': '136',
#   'ls': '230',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '897.0'},
#  {'id': '43',
#   'terrestrial_data': '2012-12-24',
#   'sol': '137',
#   'ls': '231',
#   'month': '8',
#   'min_temp': '-64.0',
#   'pressure': '896.0'},
#  {'id': '44',
#   'terrestrial_data': '2012-12-25',
#   'sol': '138',
#   'ls': '232',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '899.0'},
#  {'id': '45',
#   'terrestrial_data': '2012-12-26',
#   'sol': '139',
#   'ls': '232',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '899.0'},
#  {'id': '47',
#   'terrestrial_data': '2012-12-27',
#   'sol': '140',
#   'ls': '233',
#   'month': '8',
#   'min_temp': '-66.0',
#   'pressure': '903.0'},
#  {'id': '48',
#   'terrestrial_data': '2012-12-28',
#   'sol': '141',
#   'ls': '233',
#   'month': '8',
#   'min_temp': '-64.0',
#   'pressure': '904.0'},
#  {'id': '49',
#   'terrestrial_data': '2012-12-29',
#   'sol': '142',
#   'ls': '234',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '906.0'},
#  {'id': '50',
#   'terrestrial_data': '2012-12-31',
#   'sol': '143',
#   'ls': '235',
#   'month': '8',
#   'min_temp': '-63.0',
#   'pressure': '908.0'},
#  {'id': '51',
#   'terrestrial_data': '2013-01-01',
#   'sol': '144',
#   'ls': '235',
#   'month': '8',
#   'min_temp': '-64.0',
#   'pressure': '907.0'},
#  {'id': '52',
#   'terrestrial_data': '2013-01-02',
#   'sol': '145',
#   'ls': '236',
#   'month': '8',
#   'min_temp': '-64.0',
#   'pressure': '909.0'},
#  {'id': '53',
#   'terrestrial_data': '2013-01-03',
#   'sol': '146',
#   'ls': '237',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '908.0'},
#  {'id': '54',
#   'terrestrial_data': '2013-01-04',
#   'sol': '147',
#   'ls': '237',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '914.0'},
#  {'id': '55',
#   'terrestrial_data': '2013-01-05',
#   'sol': '148',
#   'ls': '238',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '912.0'},
#  {'id': '56',
#   'terrestrial_data': '2013-01-06',
#   'sol': '149',
#   'ls': '239',
#   'month': '8',
#   'min_temp': '-65.0',
#   'pressure': '914.0'},
#  {'id': '58',
#   'terrestrial_data': '2013-01-07',
#   'sol': '150',
#   'ls': '239',
#   'month': '8',
#   'min_temp': '-64.0',
#   'pressure': '913.0'},
#  {'id': '59',
#   'terrestrial_data': '2013-01-08',
#   'sol': '151',
#   'ls': '240',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '915.0'},
#  {'id': '60',
#   'terrestrial_data': '2013-01-09',
#   'sol': '152',
#   'ls': '241',
#   'month': '9',
#   'min_temp': '-63.0',
#   'pressure': '914.0'},
#  {'id': '61',
#   'terrestrial_data': '2013-01-10',
#   'sol': '153',
#   'ls': '241',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '915.0'},
#  {'id': '62',
#   'terrestrial_data': '2013-01-11',
#   'sol': '154',
#   'ls': '242',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '917.0'},
#  {'id': '63',
#   'terrestrial_data': '2013-01-12',
#   'sol': '155',
#   'ls': '243',
#   'month': '9',
#   'min_temp': '-64.0',
#   'pressure': '917.0'},
#  {'id': '64',
#   'terrestrial_data': '2013-01-13',
#   'sol': '156',
#   'ls': '243',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '922.0'},
#  {'id': '65',
#   'terrestrial_data': '2013-01-14',
#   'sol': '157',
#   'ls': '244',
#   'month': '9',
#   'min_temp': '-64.0',
#   'pressure': '920.0'},
#  {'id': '66',
#   'terrestrial_data': '2013-01-15',
#   'sol': '158',
#   'ls': '245',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '922.0'},
#  {'id': '67',
#   'terrestrial_data': '2013-01-16',
#   'sol': '159',
#   'ls': '245',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '918.0'},
#  {'id': '69',
#   'terrestrial_data': '2013-01-17',
#   'sol': '160',
#   'ls': '246',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '919.0'},
#  {'id': '70',
#   'terrestrial_data': '2013-01-18',
#   'sol': '161',
#   'ls': '246',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '919.0'},
#  {'id': '71',
#   'terrestrial_data': '2013-01-19',
#   'sol': '162',
#   'ls': '247',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '919.0'},
#  {'id': '72',
#   'terrestrial_data': '2013-01-20',
#   'sol': '163',
#   'ls': '248',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '919.0'},
#  {'id': '73',
#   'terrestrial_data': '2013-01-21',
#   'sol': '164',
#   'ls': '248',
#   'month': '9',
#   'min_temp': '-64.0',
#   'pressure': '919.0'},
#  {'id': '74',
#   'terrestrial_data': '2013-01-22',
#   'sol': '165',
#   'ls': '249',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '922.0'},
#  {'id': '75',
#   'terrestrial_data': '2013-01-23',
#   'sol': '166',
#   'ls': '250',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '922.0'},
#  {'id': '76',
#   'terrestrial_data': '2013-01-24',
#   'sol': '167',
#   'ls': '250',
#   'month': '9',
#   'min_temp': '-65.0',
#   'pressure': '920.0'},
#  {'id': '77',
#   'terrestrial_data': '2013-01-25',
#   'sol': '168',
#   'ls': '251',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '923.0'},
#  {'id': '78',
#   'terrestrial_data': '2013-01-26',
#   'sol': '169',
#   'ls': '252',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '922.0'},
#  {'id': '80',
#   'terrestrial_data': '2013-01-27',
#   'sol': '170',
#   'ls': '252',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '925.0'},
#  {'id': '81',
#   'terrestrial_data': '2013-01-28',
#   'sol': '171',
#   'ls': '253',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '925.0'},
#  {'id': '82',
#   'terrestrial_data': '2013-01-29',
#   'sol': '172',
#   'ls': '254',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '923.0'},
#  {'id': '83',
#   'terrestrial_data': '2013-01-30',
#   'sol': '173',
#   'ls': '254',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '920.0'},
#  {'id': '84',
#   'terrestrial_data': '2013-01-31',
#   'sol': '174',
#   'ls': '255',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '921.0'},
#  {'id': '85',
#   'terrestrial_data': '2013-02-01',
#   'sol': '175',
#   'ls': '256',
#   'month': '9',
#   'min_temp': '-68.0',
#   'pressure': '921.0'},
#  {'id': '86',
#   'terrestrial_data': '2013-02-02',
#   'sol': '176',
#   'ls': '256',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '920.0'},
#  {'id': '87',
#   'terrestrial_data': '2013-02-03',
#   'sol': '177',
#   'ls': '257',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '921.0'},
#  {'id': '88',
#   'terrestrial_data': '2013-02-04',
#   'sol': '178',
#   'ls': '258',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '920.0'},
#  {'id': '89',
#   'terrestrial_data': '2013-02-06',
#   'sol': '179',
#   'ls': '258',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '920.0'},
#  {'id': '91',
#   'terrestrial_data': '2013-02-07',
#   'sol': '180',
#   'ls': '259',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '919.0'},
#  {'id': '92',
#   'terrestrial_data': '2013-02-08',
#   'sol': '181',
#   'ls': '260',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '918.0'},
#  {'id': '93',
#   'terrestrial_data': '2013-02-09',
#   'sol': '182',
#   'ls': '260',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '921.0'},
#  {'id': '94',
#   'terrestrial_data': '2013-02-10',
#   'sol': '183',
#   'ls': '261',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '921.0'},
#  {'id': '95',
#   'terrestrial_data': '2013-02-11',
#   'sol': '184',
#   'ls': '261',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '923.0'},
#  {'id': '96',
#   'terrestrial_data': '2013-02-12',
#   'sol': '185',
#   'ls': '262',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '923.0'},
#  {'id': '97',
#   'terrestrial_data': '2013-02-13',
#   'sol': '186',
#   'ls': '263',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '922.0'},
#  {'id': '98',
#   'terrestrial_data': '2013-02-14',
#   'sol': '187',
#   'ls': '263',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '921.0'},
#  {'id': '99',
#   'terrestrial_data': '2013-02-15',
#   'sol': '188',
#   'ls': '264',
#   'month': '9',
#   'min_temp': '-68.0',
#   'pressure': '920.0'},
#  {'id': '100',
#   'terrestrial_data': '2013-02-16',
#   'sol': '189',
#   'ls': '265',
#   'month': '9',
#   'min_temp': '-68.0',
#   'pressure': '920.0'},
#  {'id': '102',
#   'terrestrial_data': '2013-02-17',
#   'sol': '190',
#   'ls': '265',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '917.0'},
#  {'id': '103',
#   'terrestrial_data': '2013-02-18',
#   'sol': '191',
#   'ls': '266',
#   'month': '9',
#   'min_temp': '-67.0',
#   'pressure': '921.0'},
#  {'id': '106',
#   'terrestrial_data': '2013-02-23',
#   'sol': '196',
#   'ls': '269',
#   'month': '9',
#   'min_temp': '-66.0',
#   'pressure': '916.0'},
#  {'id': '107',
#   'terrestrial_data': '2013-02-24',
#   'sol': '197',
#   'ls': '270',
#   'month': '10',
#   'min_temp': '-68.0',
#   'pressure': '915.0'},
#  {'id': '108',
#   'terrestrial_data': '2013-02-25',
#   'sol': '198',
#   'ls': '271',
#   'month': '10',
#   'min_temp': '-67.0',
#   'pressure': '914.0'},
#  {'id': '109',
#   'terrestrial_data': '2013-02-26',
#   'sol': '199',
#   'ls': '271',
#   'month': '10',
#   'min_temp': '-66.0',
#   'pressure': '917.0'},
#  {'id': '116',
#   'terrestrial_data': '2013-03-23',
#   'sol': '223',
#   'ls': '287',
#   'month': '10',
#   'min_temp': '-71.0',
#   'pressure': '895.0'},
#  {'id': '117',
#   'terrestrial_data': '2013-03-24',
#   'sol': '224',
#   'ls': '287',
#   'month': '10',
#   'min_temp': '-69.0',
#   'pressure': '894.0'},
#  {'id': '118',
#   'terrestrial_data': '2013-03-25',
#   'sol': '225',
#   'ls': '288',
#   'month': '10',
#   'min_temp': '-71.0',
#   'pressure': '894.0'},
#  {'id': '119',
#   'terrestrial_data': '2013-03-26',
#   'sol': '226',
#   'ls': '288',
#   'month': '10',
#   'min_temp': '-70.0',
#   'pressure': '894.0'},
#  {'id': '120',
#   'terrestrial_data': '2013-03-27',
#   'sol': '227',
#   'ls': '289',
#   'month': '10',
#   'min_temp': '-70.0',
#   'pressure': '892.0'},
#  {'id': '121',
#   'terrestrial_data': '2013-03-28',
#   'sol': '228',
#   'ls': '290',
#   'month': '10',
#   'min_temp': '-71.0',
#   'pressure': '894.0'},
#  {'id': '122',
#   'terrestrial_data': '2013-03-29',
#   'sol': '229',
#   'ls': '290',
#   'month': '10',
#   'min_temp': '-69.0',
#   'pressure': '894.0'},
#  {'id': '124',
#   'terrestrial_data': '2013-03-30',
#   'sol': '230',
#   'ls': '291',
#   'month': '10',
#   'min_temp': '-69.0',
#   'pressure': '888.0'},
#  {'id': '125',
#   'terrestrial_data': '2013-03-31',
#   'sol': '231',
#   'ls': '292',
#   'month': '10',
#   'min_temp': '-71.0',
#   'pressure': '890.0'},
#  {'id': '126',
#   'terrestrial_data': '2013-04-01',
#   'sol': '232',
#   'ls': '292',
#   'month': '10',
#   'min_temp': '-69.0',
#   'pressure': '888.0'},
#  {'id': '127',
#   'terrestrial_data': '2013-04-02',
#   'sol': '233',
#   'ls': '293',
#   'month': '10',
#   'min_temp': '-69.0',
#   'pressure': '889.0'},
#  {'id': '128',
#   'terrestrial_data': '2013-04-03',
#   'sol': '234',
#   'ls': '293',
#   'month': '10',
#   'min_temp': '-69.0',
#   'pressure': '890.0'},
#  {'id': '129',
#   'terrestrial_data': '2013-04-04',
#   'sol': '235',
#   'ls': '294',
#   'month': '10',
#   'min_temp': '-70.0',
#   'pressure': '886.0'},
#  {'id': '130',
#   'terrestrial_data': '2013-04-05',
#   'sol': '236',
#   'ls': '295',
#   'month': '10',
#   'min_temp': '-72.0',
#   'pressure': '886.0'},
#  {'id': '131',
#   'terrestrial_data': '2013-04-06',
#   'sol': '237',
#   'ls': '295',
#   'month': '10',
#   'min_temp': '-71.0',
#   'pressure': '883.0'},
#  {'id': '132',
#   'terrestrial_data': '2013-04-07',
#   'sol': '238',
#   'ls': '296',
#   'month': '10',
#   'min_temp': '-70.0',
#   'pressure': '885.0'},
#  {'id': '133',
#   'terrestrial_data': '2013-04-08',
#   'sol': '239',
#   'ls': '297',
#   'month': '10',
#   'min_temp': '-73.0',
#   'pressure': '885.0'},
#  {'id': '135',
#   'terrestrial_data': '2013-04-09',
#   'sol': '240',
#   'ls': '297',
#   'month': '10',
#   'min_temp': '-70.0',
#   'pressure': '884.0'},
#  {'id': '136',
#   'terrestrial_data': '2013-04-10',
#   'sol': '241',
#   'ls': '298',
#   'month': '10',
#   'min_temp': '-72.0',
#   'pressure': '884.0'},
#  {'id': '137',
#   'terrestrial_data': '2013-04-11',
#   'sol': '242',
#   'ls': '298',
#   'month': '10',
#   'min_temp': '-70.0',
#   'pressure': '881.0'},
#  {'id': '138',
#   'terrestrial_data': '2013-04-12',
#   'sol': '243',
#   'ls': '299',
#   'month': '10',
#   'min_temp': '-71.0',
#   'pressure': '884.0'},
#  {'id': '139',
#   'terrestrial_data': '2013-04-13',
#   'sol': '244',
#   'ls': '300',
#   'month': '11',
#   'min_temp': '-69.0',
#   'pressure': '878.0'},
#  {'id': '140',
#   'terrestrial_data': '2013-04-14',
#   'sol': '245',
#   'ls': '300',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '879.0'},
#  {'id': '141',
#   'terrestrial_data': '2013-04-15',
#   'sol': '246',
#   'ls': '301',
#   'month': '11',
#   'min_temp': '-73.0',
#   'pressure': '878.0'},
#  {'id': '142',
#   'terrestrial_data': '2013-04-16',
#   'sol': '247',
#   'ls': '301',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '873.0'},
#  {'id': '143',
#   'terrestrial_data': '2013-04-17',
#   'sol': '248',
#   'ls': '302',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '877.0'},
#  {'id': '144',
#   'terrestrial_data': '2013-04-18',
#   'sol': '249',
#   'ls': '303',
#   'month': '11',
#   'min_temp': '-69.0',
#   'pressure': '873.0'},
#  {'id': '146',
#   'terrestrial_data': '2013-04-19',
#   'sol': '250',
#   'ls': '303',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '877.0'},
#  {'id': '147',
#   'terrestrial_data': '2013-04-20',
#   'sol': '251',
#   'ls': '304',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '876.0'},
#  {'id': '148',
#   'terrestrial_data': '2013-04-22',
#   'sol': '252',
#   'ls': '304',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '874.0'},
#  {'id': '149',
#   'terrestrial_data': '2013-04-23',
#   'sol': '253',
#   'ls': '305',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '877.0'},
#  {'id': '150',
#   'terrestrial_data': '2013-04-24',
#   'sol': '254',
#   'ls': '306',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '871.0'},
#  {'id': '151',
#   'terrestrial_data': '2013-04-25',
#   'sol': '255',
#   'ls': '306',
#   'month': '11',
#   'min_temp': '-69.0',
#   'pressure': '877.0'},
#  {'id': '152',
#   'terrestrial_data': '2013-04-26',
#   'sol': '256',
#   'ls': '307',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '871.0'},
#  {'id': '153',
#   'terrestrial_data': '2013-04-27',
#   'sol': '257',
#   'ls': '308',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '871.0'},
#  {'id': '154',
#   'terrestrial_data': '2013-04-28',
#   'sol': '258',
#   'ls': '308',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '869.0'},
#  {'id': '155',
#   'terrestrial_data': '2013-04-29',
#   'sol': '259',
#   'ls': '309',
#   'month': '11',
#   'min_temp': '-72.0',
#   'pressure': '871.0'},
#  {'id': '157',
#   'terrestrial_data': '2013-04-30',
#   'sol': '260',
#   'ls': '309',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '875.0'},
#  {'id': '158',
#   'terrestrial_data': '2013-05-01',
#   'sol': '261',
#   'ls': '310',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '868.0'},
#  {'id': '161',
#   'terrestrial_data': '2013-05-08',
#   'sol': '268',
#   'ls': '314',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '864.0'},
#  {'id': '162',
#   'terrestrial_data': '2013-05-09',
#   'sol': '269',
#   'ls': '315',
#   'month': '11',
#   'min_temp': '-72.0',
#   'pressure': '866.0'},
#  {'id': '164',
#   'terrestrial_data': '2013-05-10',
#   'sol': '270',
#   'ls': '315',
#   'month': '11',
#   'min_temp': '-67.0',
#   'pressure': '863.0'},
#  {'id': '165',
#   'terrestrial_data': '2013-05-11',
#   'sol': '271',
#   'ls': '316',
#   'month': '11',
#   'min_temp': '-69.0',
#   'pressure': '864.0'},
#  {'id': '166',
#   'terrestrial_data': '2013-05-12',
#   'sol': '272',
#   'ls': '316',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '864.0'},
#  {'id': '167',
#   'terrestrial_data': '2013-05-13',
#   'sol': '273',
#   'ls': '317',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '861.0'},
#  {'id': '168',
#   'terrestrial_data': '2013-05-14',
#   'sol': '274',
#   'ls': '318',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '861.0'},
#  {'id': '169',
#   'terrestrial_data': '2013-05-15',
#   'sol': '275',
#   'ls': '318',
#   'month': '11',
#   'min_temp': '-67.0',
#   'pressure': '860.0'},
#  {'id': '244',
#   'terrestrial_data': '2013-05-16',
#   'sol': '276',
#   'ls': '319',
#   'month': '11',
#   'min_temp': '-69.0',
#   'pressure': '858.0'},
#  {'id': '245',
#   'terrestrial_data': '2013-05-17',
#   'sol': '277',
#   'ls': '319',
#   'month': '11',
#   'min_temp': '-69.0',
#   'pressure': '857.0'},
#  {'id': '246',
#   'terrestrial_data': '2013-05-18',
#   'sol': '278',
#   'ls': '320',
#   'month': '11',
#   'min_temp': '-67.0',
#   'pressure': '855.0'},
#  {'id': '247',
#   'terrestrial_data': '2013-05-19',
#   'sol': '279',
#   'ls': '321',
#   'month': '11',
#   'min_temp': '-68.0',
#   'pressure': '856.0'},
#  {'id': '248',
#   'terrestrial_data': '2013-05-20',
#   'sol': '280',
#   'ls': '321',
#   'month': '11',
#   'min_temp': '-69.0',
#   'pressure': '856.0'},
#  {'id': '249',
#   'terrestrial_data': '2013-05-21',
#   'sol': '281',
#   'ls': '322',
#   'month': '11',
#   'min_temp': '-68.0',
#   'pressure': '855.0'},
#  {'id': '250',
#   'terrestrial_data': '2013-05-22',
#   'sol': '282',
#   'ls': '322',
#   'month': '11',
#   'min_temp': '-72.0',
#   'pressure': '856.0'},
#  {'id': '251',
#   'terrestrial_data': '2013-05-23',
#   'sol': '283',
#   'ls': '323',
#   'month': '11',
#   'min_temp': '-68.0',
#   'pressure': '854.0'},
#  {'id': '252',
#   'terrestrial_data': '2013-05-24',
#   'sol': '284',
#   'ls': '323',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '854.0'},
#  {'id': '253',
#   'terrestrial_data': '2013-05-25',
#   'sol': '285',
#   'ls': '324',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '852.0'},
#  {'id': '254',
#   'terrestrial_data': '2013-05-26',
#   'sol': '286',
#   'ls': '325',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '854.0'},
#  {'id': '255',
#   'terrestrial_data': '2013-05-27',
#   'sol': '287',
#   'ls': '325',
#   'month': '11',
#   'min_temp': '-72.0',
#   'pressure': '856.0'},
#  {'id': '256',
#   'terrestrial_data': '2013-05-29',
#   'sol': '288',
#   'ls': '326',
#   'month': '11',
#   'min_temp': '-69.0',
#   'pressure': '854.0'},
#  {'id': '257',
#   'terrestrial_data': '2013-05-30',
#   'sol': '289',
#   'ls': '326',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '854.0'},
#  {'id': '258',
#   'terrestrial_data': '2013-05-31',
#   'sol': '290',
#   'ls': '327',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '853.0'},
#  {'id': '259',
#   'terrestrial_data': '2013-06-01',
#   'sol': '291',
#   'ls': '327',
#   'month': '11',
#   'min_temp': '-70.0',
#   'pressure': '853.0'},
#  {'id': '260',
#   'terrestrial_data': '2013-06-02',
#   'sol': '292',
#   'ls': '328',
#   'month': '11',
#   'min_temp': '-71.0',
#   'pressure': '853.0'},
#  {'id': '261',
#   'terrestrial_data': '2013-06-03',
#   'sol': '293',
#   'ls': '329',
#   'month': '11',
#   'min_temp': '-72.0',
#   'pressure': '850.0'},
#  {'id': '262',
#   'terrestrial_data': '2013-06-04',
#   'sol': '294',
#   'ls': '329',
#   'month': '11',
#   'min_temp': '-72.0',
#   'pressure': '852.0'},
#  {'id': '263',
#   'terrestrial_data': '2013-06-05',
#   'sol': '295',
#   'ls': '330',
#   'month': '12',
#   'min_temp': '-71.0',
#   'pressure': '853.0'},
#  {'id': '264',
#   'terrestrial_data': '2013-06-06',
#   'sol': '296',
#   'ls': '330',
#   'month': '12',
#   'min_temp': '-71.0',
#   'pressure': '850.0'},
#  {'id': '265',
#   'terrestrial_data': '2013-06-07',
#   'sol': '297',
#   'ls': '331',
#   'month': '12',
#   'min_temp': '-72.0',
#   'pressure': '849.0'},
#  {'id': '266',
#   'terrestrial_data': '2013-06-08',
#   'sol': '298',
#   'ls': '331',
#   'month': '12',
#   'min_temp': '-72.0',
#   'pressure': '850.0'},
#  {'id': '267',
#   'terrestrial_data': '2013-06-09',
#   'sol': '299',
#   'ls': '332',
#   'month': '12',
#   'min_temp': '-71.0',
#   'pressure': '849.0'},
#  {'id': '286',
#   'terrestrial_data': '2013-06-10',
#   'sol': '300',
#   'ls': '333',
#   'month': '12',
#   'min_temp': '-72.0',
#   'pressure': '852.0'},
#  {'id': '276',
#   'terrestrial_data': '2013-06-11',
#   'sol': '301',
#   'ls': '333',
#   'month': '12',
#   'min_temp': '-73.0',
#   'pressure': '852.0'},
#  {'id': '287',
#   'terrestrial_data': '2013-06-12',
#   'sol': '302',
#   'ls': '334',
#   'month': '12',
#   'min_temp': '-71.0',
#   'pressure': '850.0'},
#  {'id': '283',
#   'terrestrial_data': '2013-06-13',
#   'sol': '303',
#   'ls': '334',
#   'month': '12',
#   'min_temp': '-71.0',
#   'pressure': '849.0'},
#  {'id': '281',
#   'terrestrial_data': '2013-06-14',
#   'sol': '304',
#   'ls': '335',
#   'month': '12',
#   'min_temp': '-70.0',
#   'pressure': '848.0'},
#  {'id': '275',
#   'terrestrial_data': '2013-06-15',
#   'sol': '305',
#   'ls': '335',
#   'month': '12',
#   'min_temp': '-71.0',
#   'pressure': '847.0'},
#  {'id': '280',
#   'terrestrial_data': '2013-06-16',
#   'sol': '306',
#   'ls': '336',
#   'month': '12',
#   'min_temp': '-71.0',
#   'pressure': '848.0'},
#  {'id': '279',
#   'terrestrial_data': '2013-06-17',
#   'sol': '307',
#   'ls': '336',
#   'month': '12',
#   'min_temp': '-72.0',
#   'pressure': '851.0'},
#  {'id': '282',
#   'terrestrial_data': '2013-06-18',
#   'sol': '308',
#   'ls': '337',
#   'month': '12',
#   'min_temp': '-73.0',
#   'pressure': '850.0'},
#  {'id': '284',
#   'terrestrial_data': '2013-06-19',
#   'sol': '309',
#   'ls': '338',
#   'month': '12',
#   'min_temp': '-72.0',
#   'pressure': '848.0'},
#  {'id': '278',
#   'terrestrial_data': '2013-06-20',
#   'sol': '310',
#   'ls': '338',
#   'month': '12',
#   'min_temp': '-71.0',
#   'pressure': '849.0'},
#  {'id': '277',
#   'terrestrial_data': '2013-06-21',
#   'sol': '311',
#   'ls': '339',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '846.0'},
#  {'id': '285',
#   'terrestrial_data': '2013-06-22',
#   'sol': '312',
#   'ls': '339',
#   'month': '12',
#   'min_temp': '-71.0',
#   'pressure': '845.0'},
#  {'id': '274',
#   'terrestrial_data': '2013-06-23',
#   'sol': '313',
#   'ls': '340',
#   'month': '12',
#   'min_temp': '-77.0',
#   'pressure': '849.0'},
#  {'id': '272',
#   'terrestrial_data': '2013-06-24',
#   'sol': '314',
#   'ls': '340',
#   'month': '12',
#   'min_temp': '-73.0',
#   'pressure': '848.0'},
#  {'id': '273',
#   'terrestrial_data': '2013-06-25',
#   'sol': '315',
#   'ls': '341',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '850.0'},
#  {'id': '288',
#   'terrestrial_data': '2013-06-26',
#   'sol': '316',
#   'ls': '341',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '851.0'},
#  {'id': '268',
#   'terrestrial_data': '2013-06-27',
#   'sol': '317',
#   'ls': '342',
#   'month': '12',
#   'min_temp': '-72.0',
#   'pressure': '849.0'},
#  {'id': '270',
#   'terrestrial_data': '2013-06-28',
#   'sol': '318',
#   'ls': '342',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '849.0'},
#  {'id': '271',
#   'terrestrial_data': '2013-06-29',
#   'sol': '319',
#   'ls': '343',
#   'month': '12',
#   'min_temp': '-73.0',
#   'pressure': '847.0'},
#  {'id': '269',
#   'terrestrial_data': '2013-06-30',
#   'sol': '320',
#   'ls': '344',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '846.0'},
#  {'id': '289',
#   'terrestrial_data': '2013-07-01',
#   'sol': '321',
#   'ls': '344',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '847.0'},
#  {'id': '291',
#   'terrestrial_data': '2013-07-02',
#   'sol': '322',
#   'ls': '345',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '849.0'},
#  {'id': '290',
#   'terrestrial_data': '2013-07-03',
#   'sol': '323',
#   'ls': '345',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '847.0'},
#  {'id': '292',
#   'terrestrial_data': '2013-07-04',
#   'sol': '324',
#   'ls': '346',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '850.0'},
#  {'id': '294',
#   'terrestrial_data': '2013-07-06',
#   'sol': '325',
#   'ls': '346',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '847.0'},
#  {'id': '295',
#   'terrestrial_data': '2013-07-07',
#   'sol': '326',
#   'ls': '347',
#   'month': '12',
#   'min_temp': '-72.0',
#   'pressure': '848.0'},
#  {'id': '296',
#   'terrestrial_data': '2013-07-08',
#   'sol': '327',
#   'ls': '347',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '848.0'},
#  {'id': '293',
#   'terrestrial_data': '2013-07-09',
#   'sol': '328',
#   'ls': '348',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '847.0'},
#  {'id': '298',
#   'terrestrial_data': '2013-07-10',
#   'sol': '329',
#   'ls': '348',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '847.0'},
#  {'id': '297',
#   'terrestrial_data': '2013-07-11',
#   'sol': '330',
#   'ls': '349',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '848.0'},
#  {'id': '303',
#   'terrestrial_data': '2013-07-12',
#   'sol': '331',
#   'ls': '349',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '848.0'},
#  {'id': '300',
#   'terrestrial_data': '2013-07-13',
#   'sol': '332',
#   'ls': '350',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '849.0'},
#  {'id': '299',
#   'terrestrial_data': '2013-07-14',
#   'sol': '333',
#   'ls': '350',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '849.0'},
#  {'id': '301',
#   'terrestrial_data': '2013-07-15',
#   'sol': '334',
#   'ls': '351',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '852.0'},
#  {'id': '302',
#   'terrestrial_data': '2013-07-16',
#   'sol': '335',
#   'ls': '352',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '852.0'},
#  {'id': '305',
#   'terrestrial_data': '2013-07-17',
#   'sol': '336',
#   'ls': '352',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '852.0'},
#  {'id': '304',
#   'terrestrial_data': '2013-07-18',
#   'sol': '337',
#   'ls': '353',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '853.0'},
#  {'id': '306',
#   'terrestrial_data': '2013-07-19',
#   'sol': '338',
#   'ls': '353',
#   'month': '12',
#   'min_temp': '-78.0',
#   'pressure': '848.0'},
#  {'id': '308',
#   'terrestrial_data': '2013-07-20',
#   'sol': '339',
#   'ls': '354',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '849.0'},
#  {'id': '307',
#   'terrestrial_data': '2013-07-21',
#   'sol': '340',
#   'ls': '354',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '851.0'},
#  {'id': '310',
#   'terrestrial_data': '2013-07-22',
#   'sol': '341',
#   'ls': '355',
#   'month': '12',
#   'min_temp': '-77.0',
#   'pressure': '852.0'},
#  {'id': '309',
#   'terrestrial_data': '2013-07-23',
#   'sol': '342',
#   'ls': '355',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '851.0'},
#  {'id': '311',
#   'terrestrial_data': '2013-07-24',
#   'sol': '343',
#   'ls': '356',
#   'month': '12',
#   'min_temp': '-77.0',
#   'pressure': '850.0'},
#  {'id': '317',
#   'terrestrial_data': '2013-07-25',
#   'sol': '344',
#   'ls': '356',
#   'month': '12',
#   'min_temp': '-77.0',
#   'pressure': '851.0'},
#  {'id': '312',
#   'terrestrial_data': '2013-07-26',
#   'sol': '345',
#   'ls': '357',
#   'month': '12',
#   'min_temp': '-77.0',
#   'pressure': '853.0'},
#  {'id': '314',
#   'terrestrial_data': '2013-07-27',
#   'sol': '346',
#   'ls': '357',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '853.0'},
#  {'id': '313',
#   'terrestrial_data': '2013-07-28',
#   'sol': '347',
#   'ls': '358',
#   'month': '12',
#   'min_temp': '-77.0',
#   'pressure': '851.0'},
#  {'id': '315',
#   'terrestrial_data': '2013-07-29',
#   'sol': '348',
#   'ls': '358',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '850.0'},
#  {'id': '316',
#   'terrestrial_data': '2013-07-30',
#   'sol': '349',
#   'ls': '359',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '852.0'},
#  {'id': '318',
#   'terrestrial_data': '2013-07-31',
#   'sol': '350',
#   'ls': '359',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '853.0'},
#  {'id': '320',
#   'terrestrial_data': '2013-08-01',
#   'sol': '351',
#   'ls': '0',
#   'month': '1',
#   'min_temp': '-75.0',
#   'pressure': '853.0'},
#  {'id': '319',
#   'terrestrial_data': '2013-08-02',
#   'sol': '352',
#   'ls': '0',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '854.0'},
#  {'id': '323',
#   'terrestrial_data': '2013-08-03',
#   'sol': '353',
#   'ls': '1',
#   'month': '1',
#   'min_temp': '-75.0',
#   'pressure': '855.0'},
#  {'id': '322',
#   'terrestrial_data': '2013-08-04',
#   'sol': '354',
#   'ls': '1',
#   'month': '1',
#   'min_temp': '-75.0',
#   'pressure': '857.0'},
#  {'id': '321',
#   'terrestrial_data': '2013-08-05',
#   'sol': '355',
#   'ls': '2',
#   'month': '1',
#   'min_temp': '-75.0',
#   'pressure': '857.0'},
#  {'id': '324',
#   'terrestrial_data': '2013-08-06',
#   'sol': '356',
#   'ls': '2',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '856.0'},
#  {'id': '325',
#   'terrestrial_data': '2013-08-07',
#   'sol': '357',
#   'ls': '3',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '857.0'},
#  {'id': '326',
#   'terrestrial_data': '2013-08-17',
#   'sol': '366',
#   'ls': '7',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '861.0'},
#  {'id': '328',
#   'terrestrial_data': '2013-08-18',
#   'sol': '367',
#   'ls': '8',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '862.0'},
#  {'id': '330',
#   'terrestrial_data': '2013-08-19',
#   'sol': '368',
#   'ls': '8',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '863.0'},
#  {'id': '331',
#   'terrestrial_data': '2013-08-20',
#   'sol': '369',
#   'ls': '9',
#   'month': '1',
#   'min_temp': '-75.0',
#   'pressure': '865.0'},
#  {'id': '332',
#   'terrestrial_data': '2013-08-21',
#   'sol': '370',
#   'ls': '9',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '865.0'},
#  {'id': '333',
#   'terrestrial_data': '2013-08-22',
#   'sol': '371',
#   'ls': '10',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '865.0'},
#  {'id': '334',
#   'terrestrial_data': '2013-08-23',
#   'sol': '372',
#   'ls': '10',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '866.0'},
#  {'id': '335',
#   'terrestrial_data': '2013-08-24',
#   'sol': '373',
#   'ls': '11',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '866.0'},
#  {'id': '337',
#   'terrestrial_data': '2013-08-25',
#   'sol': '374',
#   'ls': '11',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '866.0'},
#  {'id': '336',
#   'terrestrial_data': '2013-08-26',
#   'sol': '375',
#   'ls': '12',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '867.0'},
#  {'id': '340',
#   'terrestrial_data': '2013-08-27',
#   'sol': '376',
#   'ls': '12',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '870.0'},
#  {'id': '338',
#   'terrestrial_data': '2013-08-28',
#   'sol': '377',
#   'ls': '13',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '870.0'},
#  {'id': '339',
#   'terrestrial_data': '2013-08-29',
#   'sol': '378',
#   'ls': '13',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '869.0'},
#  {'id': '341',
#   'terrestrial_data': '2013-08-30',
#   'sol': '379',
#   'ls': '14',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '870.0'},
#  {'id': '343',
#   'terrestrial_data': '2013-08-31',
#   'sol': '380',
#   'ls': '14',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '870.0'},
#  {'id': '345',
#   'terrestrial_data': '2013-09-01',
#   'sol': '381',
#   'ls': '15',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '871.0'},
#  {'id': '344',
#   'terrestrial_data': '2013-09-02',
#   'sol': '382',
#   'ls': '15',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '872.0'},
#  {'id': '342',
#   'terrestrial_data': '2013-09-03',
#   'sol': '383',
#   'ls': '16',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '874.0'},
#  {'id': '346',
#   'terrestrial_data': '2013-09-04',
#   'sol': '384',
#   'ls': '16',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '875.0'},
#  {'id': '351',
#   'terrestrial_data': '2013-09-05',
#   'sol': '385',
#   'ls': '17',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '874.0'},
#  {'id': '347',
#   'terrestrial_data': '2013-09-06',
#   'sol': '386',
#   'ls': '17',
#   'month': '1',
# ...
#   'sol': '983',
#   'ls': '340',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '840.0'},
#  {'id': '915',
#   'terrestrial_data': '2015-05-14',
#   'sol': '984',
#   'ls': '341',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '840.0'},
#  {'id': '918',
#   'terrestrial_data': '2015-05-15',
#   'sol': '985',
#   'ls': '342',
#   'month': '12',
#   'min_temp': '-78.0',
#   'pressure': '840.0'},
#  {'id': '919',
#   'terrestrial_data': '2015-05-16',
#   'sol': '986',
#   'ls': '342',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '840.0'},
#  {'id': '920',
#   'terrestrial_data': '2015-05-17',
#   'sol': '987',
#   'ls': '343',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '839.0'},
#  {'id': '922',
#   'terrestrial_data': '2015-05-18',
#   'sol': '988',
#   'ls': '343',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '840.0'},
#  {'id': '921',
#   'terrestrial_data': '2015-05-19',
#   'sol': '989',
#   'ls': '344',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '841.0'},
#  {'id': '923',
#   'terrestrial_data': '2015-05-20',
#   'sol': '990',
#   'ls': '344',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '839.0'},
#  {'id': '926',
#   'terrestrial_data': '2015-05-21',
#   'sol': '991',
#   'ls': '345',
#   'month': '12',
#   'min_temp': '-73.0',
#   'pressure': '840.0'},
#  {'id': '924',
#   'terrestrial_data': '2015-05-22',
#   'sol': '992',
#   'ls': '345',
#   'month': '12',
#   'min_temp': '-73.0',
#   'pressure': '842.0'},
#  {'id': '927',
#   'terrestrial_data': '2015-05-23',
#   'sol': '993',
#   'ls': '346',
#   'month': '12',
#   'min_temp': '-73.0',
#   'pressure': '840.0'},
#  {'id': '925',
#   'terrestrial_data': '2015-05-24',
#   'sol': '994',
#   'ls': '346',
#   'month': '12',
#   'min_temp': '-79.0',
#   'pressure': '842.0'},
#  {'id': '929',
#   'terrestrial_data': '2015-05-25',
#   'sol': '995',
#   'ls': '347',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '842.0'},
#  {'id': '928',
#   'terrestrial_data': '2015-05-26',
#   'sol': '996',
#   'ls': '348',
#   'month': '12',
#   'min_temp': '-72.0',
#   'pressure': '842.0'},
#  {'id': '930',
#   'terrestrial_data': '2015-05-27',
#   'sol': '997',
#   'ls': '348',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '843.0'},
#  {'id': '931',
#   'terrestrial_data': '2015-05-28',
#   'sol': '998',
#   'ls': '349',
#   'month': '12',
#   'min_temp': '-73.0',
#   'pressure': '842.0'},
#  {'id': '932',
#   'terrestrial_data': '2015-05-30',
#   'sol': '1000',
#   'ls': '350',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '841.0'},
#  {'id': '933',
#   'terrestrial_data': '2015-05-31',
#   'sol': '1001',
#   'ls': '350',
#   'month': '12',
#   'min_temp': '-79.0',
#   'pressure': '843.0'},
#  {'id': '936',
#   'terrestrial_data': '2015-06-01',
#   'sol': '1002',
#   'ls': '351',
#   'month': '12',
#   'min_temp': '-77.0',
#   'pressure': '844.0'},
#  {'id': '934',
#   'terrestrial_data': '2015-06-02',
#   'sol': '1003',
#   'ls': '351',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '843.0'},
#  {'id': '935',
#   'terrestrial_data': '2015-06-03',
#   'sol': '1004',
#   'ls': '352',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '842.0'},
#  {'id': '939',
#   'terrestrial_data': '2015-06-04',
#   'sol': '1005',
#   'ls': '352',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '843.0'},
#  {'id': '941',
#   'terrestrial_data': '2015-06-05',
#   'sol': '1006',
#   'ls': '353',
#   'month': '12',
#   'min_temp': '-78.0',
#   'pressure': '844.0'},
#  {'id': '937',
#   'terrestrial_data': '2015-06-06',
#   'sol': '1007',
#   'ls': '353',
#   'month': '12',
#   'min_temp': '-79.0',
#   'pressure': '845.0'},
#  {'id': '940',
#   'terrestrial_data': '2015-06-07',
#   'sol': '1008',
#   'ls': '354',
#   'month': '12',
#   'min_temp': '-79.0',
#   'pressure': '844.0'},
#  {'id': '946',
#   'terrestrial_data': '2015-06-08',
#   'sol': '1009',
#   'ls': '354',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '845.0'},
#  {'id': '947',
#   'terrestrial_data': '2015-06-09',
#   'sol': '1010',
#   'ls': '355',
#   'month': '12',
#   'min_temp': '-74.0',
#   'pressure': '846.0'},
#  {'id': '948',
#   'terrestrial_data': '2015-06-10',
#   'sol': '1011',
#   'ls': '355',
#   'month': '12',
#   'min_temp': '-78.0',
#   'pressure': '845.0'},
#  {'id': '949',
#   'terrestrial_data': '2015-06-11',
#   'sol': '1012',
#   'ls': '356',
#   'month': '12',
#   'min_temp': '-81.0',
#   'pressure': '846.0'},
#  {'id': '953',
#   'terrestrial_data': '2015-06-12',
#   'sol': '1013',
#   'ls': '356',
#   'month': '12',
#   'min_temp': '-80.0',
#   'pressure': '846.0'},
#  {'id': '950',
#   'terrestrial_data': '2015-06-13',
#   'sol': '1014',
#   'ls': '357',
#   'month': '12',
#   'min_temp': '-77.0',
#   'pressure': '846.0'},
#  {'id': '951',
#   'terrestrial_data': '2015-06-14',
#   'sol': '1015',
#   'ls': '357',
#   'month': '12',
#   'min_temp': '-75.0',
#   'pressure': '847.0'},
#  {'id': '952',
#   'terrestrial_data': '2015-06-16',
#   'sol': '1016',
#   'ls': '358',
#   'month': '12',
#   'min_temp': '-76.0',
#   'pressure': '847.0'},
#  {'id': '955',
#   'terrestrial_data': '2015-06-17',
#   'sol': '1017',
#   'ls': '359',
#   'month': '12',
#   'min_temp': '-78.0',
#   'pressure': '850.0'},
#  {'id': '956',
#   'terrestrial_data': '2015-06-18',
#   'sol': '1018',
#   'ls': '359',
#   'month': '12',
#   'min_temp': '-79.0',
#   'pressure': '850.0'},
#  {'id': '954',
#   'terrestrial_data': '2015-06-19',
#   'sol': '1019',
#   'ls': '0',
#   'month': '1',
#   'min_temp': '-81.0',
#   'pressure': '849.0'},
#  {'id': '938',
#   'terrestrial_data': '2015-06-20',
#   'sol': '1020',
#   'ls': '0',
#   'month': '1',
#   'min_temp': '-63.0',
#   'pressure': '832.0'},
#  {'id': '942',
#   'terrestrial_data': '2015-06-21',
#   'sol': '1021',
#   'ls': '1',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '850.0'},
#  {'id': '944',
#   'terrestrial_data': '2015-06-22',
#   'sol': '1022',
#   'ls': '1',
#   'month': '1',
#   'min_temp': '-75.0',
#   'pressure': '852.0'},
#  {'id': '943',
#   'terrestrial_data': '2015-06-23',
#   'sol': '1023',
#   'ls': '2',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '851.0'},
#  {'id': '945',
#   'terrestrial_data': '2015-06-24',
#   'sol': '1024',
#   'ls': '2',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '851.0'},
#  {'id': '958',
#   'terrestrial_data': '2015-06-25',
#   'sol': '1025',
#   'ls': '3',
#   'month': '1',
#   'min_temp': '-74.0',
#   'pressure': '851.0'},
#  {'id': '957',
#   'terrestrial_data': '2015-06-26',
#   'sol': '1026',
#   'ls': '3',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '851.0'},
#  {'id': '960',
#   'terrestrial_data': '2015-06-28',
#   'sol': '1028',
#   'ls': '4',
#   'month': '1',
#   'min_temp': '-75.0',
#   'pressure': '853.0'},
#  {'id': '959',
#   'terrestrial_data': '2015-06-29',
#   'sol': '1029',
#   'ls': '5',
#   'month': '1',
#   'min_temp': '-75.0',
#   'pressure': '856.0'},
#  {'id': '961',
#   'terrestrial_data': '2015-06-30',
#   'sol': '1030',
#   'ls': '5',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '855.0'},
#  {'id': '963',
#   'terrestrial_data': '2015-07-01',
#   'sol': '1031',
#   'ls': '6',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '854.0'},
#  {'id': '962',
#   'terrestrial_data': '2015-07-02',
#   'sol': '1032',
#   'ls': '6',
#   'month': '1',
#   'min_temp': '-74.0',
#   'pressure': '854.0'},
#  {'id': '965',
#   'terrestrial_data': '2015-07-03',
#   'sol': '1033',
#   'ls': '7',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '856.0'},
#  {'id': '964',
#   'terrestrial_data': '2015-07-04',
#   'sol': '1034',
#   'ls': '7',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '859.0'},
#  {'id': '966',
#   'terrestrial_data': '2015-07-05',
#   'sol': '1035',
#   'ls': '8',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '857.0'},
#  {'id': '967',
#   'terrestrial_data': '2015-07-06',
#   'sol': '1036',
#   'ls': '8',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '856.0'},
#  {'id': '968',
#   'terrestrial_data': '2015-07-07',
#   'sol': '1037',
#   'ls': '9',
#   'month': '1',
#   'min_temp': '-80.0',
#   'pressure': '856.0'},
#  {'id': '969',
#   'terrestrial_data': '2015-07-08',
#   'sol': '1038',
#   'ls': '9',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '858.0'},
#  {'id': '970',
#   'terrestrial_data': '2015-07-09',
#   'sol': '1039',
#   'ls': '10',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '857.0'},
#  {'id': '972',
#   'terrestrial_data': '2015-07-10',
#   'sol': '1040',
#   'ls': '10',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '858.0'},
#  {'id': '971',
#   'terrestrial_data': '2015-07-11',
#   'sol': '1041',
#   'ls': '11',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '859.0'},
#  {'id': '973',
#   'terrestrial_data': '2015-07-12',
#   'sol': '1042',
#   'ls': '11',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '859.0'},
#  {'id': '974',
#   'terrestrial_data': '2015-07-13',
#   'sol': '1043',
#   'ls': '12',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '860.0'},
#  {'id': '975',
#   'terrestrial_data': '2015-07-14',
#   'sol': '1044',
#   'ls': '12',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '860.0'},
#  {'id': '978',
#   'terrestrial_data': '2015-07-15',
#   'sol': '1045',
#   'ls': '13',
#   'month': '1',
#   'min_temp': '-80.0',
#   'pressure': '861.0'},
#  {'id': '979',
#   'terrestrial_data': '2015-07-16',
#   'sol': '1046',
#   'ls': '13',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '862.0'},
#  {'id': '977',
#   'terrestrial_data': '2015-07-17',
#   'sol': '1047',
#   'ls': '14',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '863.0'},
#  {'id': '976',
#   'terrestrial_data': '2015-07-18',
#   'sol': '1048',
#   'ls': '14',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '864.0'},
#  {'id': '980',
#   'terrestrial_data': '2015-07-19',
#   'sol': '1049',
#   'ls': '15',
#   'month': '1',
#   'min_temp': '-75.0',
#   'pressure': '864.0'},
#  {'id': '981',
#   'terrestrial_data': '2015-07-20',
#   'sol': '1050',
#   'ls': '15',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '863.0'},
#  {'id': '983',
#   'terrestrial_data': '2015-07-21',
#   'sol': '1051',
#   'ls': '16',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '864.0'},
#  {'id': '982',
#   'terrestrial_data': '2015-07-23',
#   'sol': '1052',
#   'ls': '16',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '865.0'},
#  {'id': '984',
#   'terrestrial_data': '2015-07-24',
#   'sol': '1053',
#   'ls': '17',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '865.0'},
#  {'id': '985',
#   'terrestrial_data': '2015-07-25',
#   'sol': '1054',
#   'ls': '17',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '867.0'},
#  {'id': '987',
#   'terrestrial_data': '2015-07-26',
#   'sol': '1055',
#   'ls': '17',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '868.0'},
#  {'id': '986',
#   'terrestrial_data': '2015-07-27',
#   'sol': '1056',
#   'ls': '18',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '868.0'},
#  {'id': '988',
#   'terrestrial_data': '2015-07-28',
#   'sol': '1057',
#   'ls': '18',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '867.0'},
#  {'id': '989',
#   'terrestrial_data': '2015-07-29',
#   'sol': '1058',
#   'ls': '19',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '868.0'},
#  {'id': '990',
#   'terrestrial_data': '2015-07-30',
#   'sol': '1059',
#   'ls': '19',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '870.0'},
#  {'id': '992',
#   'terrestrial_data': '2015-07-31',
#   'sol': '1060',
#   'ls': '20',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '870.0'},
#  {'id': '993',
#   'terrestrial_data': '2015-08-01',
#   'sol': '1061',
#   'ls': '20',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '871.0'},
#  {'id': '991',
#   'terrestrial_data': '2015-08-02',
#   'sol': '1062',
#   'ls': '21',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '871.0'},
#  {'id': '994',
#   'terrestrial_data': '2015-08-03',
#   'sol': '1063',
#   'ls': '21',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '871.0'},
#  {'id': '996',
#   'terrestrial_data': '2015-08-04',
#   'sol': '1064',
#   'ls': '22',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '871.0'},
#  {'id': '995',
#   'terrestrial_data': '2015-08-05',
#   'sol': '1065',
#   'ls': '22',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '873.0'},
#  {'id': '997',
#   'terrestrial_data': '2015-08-06',
#   'sol': '1066',
#   'ls': '23',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '875.0'},
#  {'id': '998',
#   'terrestrial_data': '2015-08-07',
#   'sol': '1067',
#   'ls': '23',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '875.0'},
#  {'id': '1000',
#   'terrestrial_data': '2015-08-08',
#   'sol': '1068',
#   'ls': '24',
#   'month': '1',
#   'min_temp': '-76.0',
#   'pressure': '874.0'},
#  {'id': '999',
#   'terrestrial_data': '2015-08-09',
#   'sol': '1069',
#   'ls': '24',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '876.0'},
#  {'id': '1001',
#   'terrestrial_data': '2015-08-10',
#   'sol': '1070',
#   'ls': '25',
#   'month': '1',
#   'min_temp': '-80.0',
#   'pressure': '877.0'},
#  {'id': '1002',
#   'terrestrial_data': '2015-08-11',
#   'sol': '1071',
#   'ls': '25',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '878.0'},
#  {'id': '1003',
#   'terrestrial_data': '2015-08-12',
#   'sol': '1072',
#   'ls': '26',
#   'month': '1',
#   'min_temp': '-78.0',
#   'pressure': '879.0'},
#  {'id': '1004',
#   'terrestrial_data': '2015-08-13',
#   'sol': '1073',
#   'ls': '26',
#   'month': '1',
#   'min_temp': '-82.0',
#   'pressure': '879.0'},
#  {'id': '1005',
#   'terrestrial_data': '2015-08-14',
#   'sol': '1074',
#   'ls': '27',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '878.0'},
#  {'id': '1006',
#   'terrestrial_data': '2015-08-15',
#   'sol': '1075',
#   'ls': '27',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '879.0'},
#  {'id': '1007',
#   'terrestrial_data': '2015-08-16',
#   'sol': '1076',
#   'ls': '28',
#   'month': '1',
#   'min_temp': '-81.0',
#   'pressure': '880.0'},
#  {'id': '1008',
#   'terrestrial_data': '2015-08-17',
#   'sol': '1077',
#   'ls': '28',
#   'month': '1',
#   'min_temp': '-79.0',
#   'pressure': '880.0'},
#  {'id': '1009',
#   'terrestrial_data': '2015-08-18',
#   'sol': '1078',
#   'ls': '29',
#   'month': '1',
#   'min_temp': '-80.0',
#   'pressure': '881.0'},
#  {'id': '1010',
#   'terrestrial_data': '2015-08-19',
#   'sol': '1079',
#   'ls': '29',
#   'month': '1',
#   'min_temp': '-80.0',
#   'pressure': '882.0'},
#  {'id': '1013',
#   'terrestrial_data': '2015-08-20',
#   'sol': '1080',
#   'ls': '29',
#   'month': '1',
#   'min_temp': '-77.0',
#   'pressure': '882.0'},
#  {'id': '1011',
#   'terrestrial_data': '2015-08-21',
#   'sol': '1081',
#   'ls': '30',
#   'month': '2',
#   'min_temp': '-77.0',
#   'pressure': '882.0'},
#  {'id': '1012',
#   'terrestrial_data': '2015-08-22',
#   'sol': '1082',
#   'ls': '30',
#   'month': '2',
#   'min_temp': '-79.0',
#   'pressure': '882.0'},
#  {'id': '1014',
#   'terrestrial_data': '2015-08-23',
#   'sol': '1083',
#   'ls': '31',
#   'month': '2',
#   'min_temp': '-80.0',
#   'pressure': '883.0'},
#  {'id': '1015',
#   'terrestrial_data': '2015-08-24',
#   'sol': '1084',
#   'ls': '31',
#   'month': '2',
#   'min_temp': '-78.0',
#   'pressure': '885.0'},
#  {'id': '1017',
#   'terrestrial_data': '2015-08-25',
#   'sol': '1085',
#   'ls': '32',
#   'month': '2',
#   'min_temp': '-79.0',
#   'pressure': '886.0'},
#  {'id': '1016',
#   'terrestrial_data': '2015-08-26',
#   'sol': '1086',
#   'ls': '32',
#   'month': '2',
#   'min_temp': '-77.0',
#   'pressure': '885.0'},
#  {'id': '1019',
#   'terrestrial_data': '2015-08-27',
#   'sol': '1087',
#   'ls': '33',
#   'month': '2',
#   'min_temp': '-78.0',
#   'pressure': '885.0'},
#  {'id': '1020',
#   'terrestrial_data': '2015-08-29',
#   'sol': '1088',
#   'ls': '33',
#   'month': '2',
#   'min_temp': '-77.0',
#   'pressure': '885.0'},
#  {'id': '1018',
#   'terrestrial_data': '2015-08-30',
#   'sol': '1089',
#   'ls': '34',
#   'month': '2',
#   'min_temp': '-76.0',
#   'pressure': '885.0'},
#  {'id': '1021',
#   'terrestrial_data': '2015-08-31',
#   'sol': '1090',
#   'ls': '34',
#   'month': '2',
#   'min_temp': '-78.0',
#   'pressure': '886.0'},
#  {'id': '1022',
#   'terrestrial_data': '2015-09-01',
#   'sol': '1091',
#   'ls': '35',
#   'month': '2',
#   'min_temp': '-77.0',
#   'pressure': '886.0'},
#  {'id': '1023',
#   'terrestrial_data': '2015-09-02',
#   'sol': '1092',
#   'ls': '35',
#   'month': '2',
#   'min_temp': '-79.0',
#   'pressure': '886.0'},
#  {'id': '1024',
#   'terrestrial_data': '2015-09-03',
#   'sol': '1093',
#   'ls': '36',
#   'month': '2',
#   'min_temp': '-77.0',
#   'pressure': '887.0'},
#  {'id': '1026',
#   'terrestrial_data': '2015-09-04',
#   'sol': '1094',
#   'ls': '36',
#   'month': '2',
#   'min_temp': '-80.0',
#   'pressure': '888.0'},
#  ...]

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
mars_weather_df = pd.DataFrame(weather_data_list, columns = ["id", "terrestrial_date", "sol", "ls", "month", "min_temp", "pressure"])

# %%
# Confirm DataFrame was created successfully
mars_weather_df
# Out:
#         id  terrestrial_date   sol   ls month min_temp pressure
# 0        2               NaN    10  155     6    -75.0    739.0
# 1       13               NaN    11  156     6    -76.0    740.0
# 2       24               NaN    12  156     6    -76.0    741.0
# 3       35               NaN    13  157     6    -74.0    732.0
# 4       46               NaN    14  157     6    -74.0    740.0
# ...    ...               ...   ...  ...   ...      ...      ...
# 1862  1889               NaN  1973  133     5    -78.0    730.0
# 1863  1892               NaN  1974  134     5    -77.0    729.0
# 1864  1894               NaN  1975  134     5    -76.0    729.0
# 1865  1893               NaN  1976  135     5    -77.0    728.0
# 1866  1895               NaN  1977  135     5    -77.0    727.0
#
# [1867 rows x 7 columns]

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
mars_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1867 non-null   object
#  1   terrestrial_date  0 non-null      float64
#  2   sol               1867 non-null   object
#  3   ls                1867 non-null   object
#  4   month             1867 non-null   object
#  5   min_temp          1867 non-null   object
#  6   pressure          1867 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 102.2+ KB

# %%
# Change data types for data analysis
mars_weather_df = mars_weather_df.astype({"sol" : int, "ls" : int, "month" : int, "min_temp" : float, "pressure" : float})
mars_weather_df["terrestrial_date"] = pd.to_datetime(mars_weather_df["terrestrial_date"])
mars_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1867 non-null   object
#  1   terrestrial_date  0 non-null      datetime64[ns]
#  2   sol               1867 non-null   int32
#  3   ls                1867 non-null   int32
#  4   month             1867 non-null   int32
#  5   min_temp          1867 non-null   float64
#  6   pressure          1867 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int32(3), object(1)
# memory usage: 80.3+ KB

# %%
# Confirm type changes were successful by examining data types again

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?

# %%
# 2. How many Martian days' worth of data are there?

# %%
# 3. What is the average low temperature by month?

# %%
# Plot the average temperature by month

# %%
# Identify the coldest and hottest months in Curiosity's location

# %%
# 4. Average pressure by Martian month

# %%
# Plot the average pressure by month

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV

# %%
browser.quit()
